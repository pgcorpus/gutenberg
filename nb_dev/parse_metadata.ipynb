# %%
import sys, os
import pandas as pd

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sys.path.append('../src/')
from metadataparser import make_df_metadata

# %% [markdown]
# Extract metadata and save as a pandas csv

# %%
path_xml = '../metadata/rdf-files.tar.bz2'
path_out = '../metadata/metadata.csv'

# %%
make_df_metadata()

# %% [markdown]
# Loading the dataframe

# %%
path_df = path_out
df = pd.read_csv(path_df,index_col='id')

# %%
df
# Out:
#                                                       title  \
# id
# PG0                                                     NaN
# PG1       The Declaration of Independence of the United ...
# PG2       The United States Bill of Rights: The Ten Orig...
# PG3                     John F. Kennedy's Inaugural Address
# PG4       Lincoln's Gettysburg Address: Given November 1...
# PG5                          The United States Constitution
# PG6                        Give Me Liberty or Give Me Death
# PG7                                   The Mayflower Compact
# PG8              Abraham Lincoln's Second Inaugural Address
# PG9               Abraham Lincoln's First Inaugural Address
# PG10                    The King James Version of the Bible
# PG11                       Alice's Adventures in Wonderland
# PG12                              Through the Looking-Glass
# PG13       The Hunting of the Snark: An Agony in Eight Fits
# PG14                            The 1990 CIA World Factbook
# ...
