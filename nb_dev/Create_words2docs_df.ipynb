# %%
import sys
import os
sys.path.append("../src/")

# %%
import pandas as pd
import numpy as np

# %%
somecounts = !ls ../data/counts/PG12*

# %%
len(somecounts)
# Out:
# 9

# %%
df = pd.DataFrame(
    data=[pd.read_table(path,header=None,na_filter=False).set_index(0)[1] for path in somecounts],
    index = [os.path.basename(path).split("_")[0] for path in somecounts],
)

# %%
df.shape
# Out:
# (9, 31191)

# %%
freqs = (df.T/df.sum(axis=1)).T

# %%
freqs
# Out:
#                 a   abaissa  abaisser   abandon  abandoned  abandonne  \
# PG12099  0.020657       NaN       NaN  0.000045        NaN        NaN
# PG12199  0.021004       NaN       NaN       NaN   0.000023        NaN
# PG12299  0.018327       NaN       NaN       NaN        NaN        NaN
# PG12399  0.004212       NaN       NaN       NaN        NaN        NaN
# PG12499       NaN       NaN       NaN       NaN        NaN        NaN
# PG12599  0.022509       NaN       NaN       NaN        NaN        NaN
# PG12899  0.018749       NaN       NaN       NaN        NaN        NaN
# PG12999  0.003829  0.000029  0.000015       NaN        NaN   0.000015
# PG1299   0.021071       NaN       NaN       NaN   0.000018        NaN
#
#          abandonné  abandonnée  abandonnées  abandonnés    ...     \
# PG12099        NaN         NaN          NaN         NaN    ...
# PG12199        NaN         NaN          NaN         NaN    ...
# PG12299        NaN         NaN          NaN         NaN    ...
# ...
